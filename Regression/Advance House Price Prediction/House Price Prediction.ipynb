# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Removing undesired features like id
df.drop('Id',inplace=True,axis=1)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Numerical Features

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(20,40))
count=1
for i in range(len(df.corr().columns)):
    plt.subplot(len(df.corr().columns)/4+1,4,count)
    sns.distplot(df[df.corr().columns[i]])
    count=count+1

# %% [markdown]
# ### Categorical Features

# %%
#extracting categorical features
#there are 43 categorical columns
num_cols = df._get_numeric_data().columns
num_cols
categorical_cols = list(set(df.columns)-set(num_cols))
len(categorical_cols)
# Out:
# 43

# %%
#comparing variious categorical features with target variable 'SalePrice'
plt.figure(figsize=(24,80), facecolor='w', edgecolor='k')
count=1
for i in range(len(categorical_cols)):
    plt.subplot(len(categorical_cols)/3+1,3,count)
    sns.barplot(categorical_cols[i],'SalePrice',data=df)
    count=count+1

# %%
#plotting the count of each category in respected categorical features
plt.figure(figsize=(24,80), facecolor='w', edgecolor='k')
count=1
for i in range(len(categorical_cols)):
    plt.subplot(len(categorical_cols)/3+1,3,count)
    sns.countplot(categorical_cols[i],data=df)
    count=count+1

# %% [markdown]
# ### Handling Missing values

# %%
#checking columns which have missing values
l = df.isnull().sum().to_dict()
cols_miss_vals = []
for key,value in l.items():
    if(value>0):
        cols_miss_vals.append(key)

# %%
cols_miss_vals
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %% [markdown]
# ### Missing values in 'LotFrontage' column

# %%
df['LotFrontage'].dtype
# Out:
# dtype('float64')

# %%
sns.scatterplot(df.index,'LotFrontage',data=df)
# Out:
# <AxesSubplot:ylabel='LotFrontage'>

# %%
#this curve shows that it follows the normal distribution
sns.distplot(df['LotFrontage'])
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='Density'>

# %%
#as both mean and median are quite closed we can replace it with anyone 
print('mean: ',df['LotFrontage'].mean(),'  median: ',df['LotFrontage'].median())
# Out:
# mean:  70.04995836802665   median:  69.0

# %%
df['LotFrontage'].fillna(df['LotFrontage'].mean(),inplace=True)

# %% [markdown]
# ### Missing values in 'Alley' column

# %%
# it is a categorical feature
df['Alley'].dtype
# Out:
# dtype('O')

# %%
# there are two categories present in this column
df['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
# as more than 50% of data is null we consider the missing values as a new category in this column
df['Alley'].isnull().sum()
# Out:
# 1369

# %%
df['Alley'].fillna("Missing",inplace=True)

# %%
df['Alley'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ###  Missing values in 'MasVnrArea' column

# %%
#its a numerical feature
df['MasVnrArea'].dtype
# Out:
# dtype('float64')

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 8

# %%
sns.distplot(df['MasVnrArea'])
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='Density'>

# %%
sns.scatterplot(df.index,'MasVnrArea',data=df)
# Out:
# <AxesSubplot:ylabel='MasVnrArea'>

# %%
# as most of the data is 0. so we replace missing values with 0.
df['MasVnrArea'].fillna(df['MasVnrArea'].mode()[0],inplace=True)

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'MasVnrType' column

# %%
df['MasVnrType'].dtype
# Out:
# dtype('O')

# %%
df['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
sns.countplot(df['MasVnrType'])
# Out:
# <AxesSubplot:xlabel='MasVnrType', ylabel='count'>

# %%
df['MasVnrType'].isnull().sum()
# Out:
# 8

# %%
#replacing it with mode
df['MasVnrType'].fillna(df['MasVnrType'].mode()[0],inplace=True)

# %%
df['MasVnrType'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'BsmtQual' column

# %%
df['BsmtQual'].dtype
# Out:
# dtype('O')

# %%
df['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
df['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
sns.countplot('BsmtQual',data=df)
# Out:
# <AxesSubplot:xlabel='BsmtQual', ylabel='count'>

# %%
df['BsmtQual'].isnull().sum()
# Out:
# 37

# %%
#replacing the missing values with the mode
df['BsmtQual'].fillna(df['BsmtQual'].mode()[0],inplace=True)

# %%
df['BsmtQual'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'BsmtCond' column

# %%
#BsmtCond: Evaluates the general condition of the basement
df['BsmtCond'].dtype
# Out:
# dtype('O')

# %%
df['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
df['BsmtCond'].isnull().sum()
# Out:
# 37

# %%
sns.countplot(df['BsmtCond'])
# Out:
# <AxesSubplot:xlabel='BsmtCond', ylabel='count'>

# %%
df['BsmtCond'].fillna(df['BsmtCond'].mode()[0],inplace=True)

# %%
df['BsmtCond'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'BsmtExposure' column

# %%
#Refers to walkout or garden level walls
df[ 'BsmtExposure'].dtype
# Out:
# dtype('O')

# %%
df[ 'BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
df[ 'BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
sns.countplot(df[ 'BsmtExposure'])
# Out:
# <AxesSubplot:xlabel='BsmtExposure', ylabel='count'>

# %%
df[ 'BsmtExposure'].isnull().sum()
# Out:
# 38

# %%
df[ 'BsmtExposure'].fillna(df[ 'BsmtExposure'].mode()[0],inplace=True)

# %%
df[ 'BsmtExposure'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ###  Missing values in 'BsmtFinType1' column

# %%
#Rating of basement finished area
df[ 'BsmtFinType1'].dtype
# Out:
# dtype('O')

# %%
df[ 'BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object)

# %%
df[ 'BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
sns.countplot(df[ 'BsmtFinType1'])
# Out:
# <AxesSubplot:xlabel='BsmtFinType1', ylabel='count'>

# %%
df[ 'BsmtFinType1'].isnull().sum()
# Out:
# 37

# %%
df[ 'BsmtFinType1'].fillna(df[ 'BsmtFinType1'].mode()[0],inplace=True)

# %%
df[ 'BsmtFinType1'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'BsmtFinType2' column

# %%
df['BsmtFinType2'].dtype
# Out:
# dtype('O')

# %%
df['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ'], dtype=object)

# %%
df['BsmtFinType2'].isnull().sum()
# Out:
# 38

# %%
sns.countplot(df['BsmtFinType2'])
# Out:
# <AxesSubplot:xlabel='BsmtFinType2', ylabel='count'>

# %%
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0],inplace=True)

# %%
df['BsmtFinType2'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'Electrical' column

# %%
df['Electrical'].dtype
# Out:
# dtype('O')

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
df['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
sns.countplot(df['Electrical'])
# Out:
# <AxesSubplot:xlabel='Electrical', ylabel='count'>

# %%
df['Electrical'].isnull().sum()
# Out:
# 1

# %%
df['Electrical'].fillna(df['Electrical'].mode()[0],inplace=True)

# %%
df['Electrical'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'FireplaceQu' column

# %%
df['FireplaceQu'].dtype
# Out:
# dtype('O')

# %%
df['FireplaceQu'].unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
df['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
sns.countplot(df['FireplaceQu'])
# Out:
# <AxesSubplot:xlabel='FireplaceQu', ylabel='count'>

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
#as more than 50% of data is missing so we make the missing values as a new category
df['FireplaceQu'].fillna("Missing",inplace=True)

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'GarageType' column

# %%
df['GarageType'].dtype
# Out:
# dtype('O')

# %%
df['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
df['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
sns.countplot(df['GarageType'])
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='count'>

# %%
df['GarageType'].isnull().sum()
# Out:
# 81

# %%
df['GarageType'].fillna(df['GarageType'].mode()[0],inplace=True)

# %%
df['GarageType'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'GarageYrBlt' column

# %%
df['GarageYrBlt'].dtype
# Out:
# dtype('float64')

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 81

# %%
sns.distplot(df['GarageYrBlt'])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
print(df['GarageYrBlt'].mean(),df['GarageYrBlt'].median())
# Out:
# 1978.5061638868744 1980.0

# %%
sns.scatterplot(df.index,df['GarageYrBlt'])
# Out:
# <AxesSubplot:ylabel='GarageYrBlt'>

# %%
# as data has not outliers so we can replace it with mean
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean(),inplace=True)

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'GarageFinish' column

# %%
df['GarageFinish'].dtype
# Out:
# dtype('O')

# %%
df['GarageFinish'].unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
df['GarageFinish'].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
sns.countplot(df['GarageFinish'])
# Out:
# <AxesSubplot:xlabel='GarageFinish', ylabel='count'>

# %%
df['GarageFinish'].isnull().sum()
# Out:
# 81

# %%
df['GarageFinish'].fillna(df['GarageFinish'].mode()[0],inplace=True)

# %%
df['GarageFinish'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ###  Missing values in 'GarageQual' column

# %%
df['GarageQual'].dtype
# Out:
# dtype('O')

# %%
df['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %%
df['GarageQual'].value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64

# %%
sns.countplot(df['GarageQual'])
# Out:
# <AxesSubplot:xlabel='GarageQual', ylabel='count'>

# %%
df['GarageQual'].isnull().sum()
# Out:
# 81

# %%
df['GarageQual'].fillna(df['GarageQual'].mode()[0],inplace=True)

# %%
df['GarageQual'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'GarageCond' column

# %%
df['GarageCond'].dtype
# Out:
# dtype('O')

# %%
df['GarageCond'].unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object)

# %%
df['GarageCond'].value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
sns.countplot(df['GarageCond'])
# Out:
# <AxesSubplot:xlabel='GarageCond', ylabel='count'>

# %%
df['GarageCond'].isnull().sum()
# Out:
# 81

# %%
df['GarageCond'].fillna(df['GarageCond'].mode()[0],inplace=True)

# %%
df['GarageCond'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'PoolQC' column

# %%
df['PoolQC'].dtype
# Out:
# dtype('O')

# %%
df['PoolQC'].unique()
# Out:
# array([nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
df['PoolQC'].value_counts()
# Out:
# Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64

# %%
sns.countplot(df['PoolQC'])
# Out:
# <AxesSubplot:xlabel='PoolQC', ylabel='count'>

# %%
df['PoolQC'].isnull().sum()
# Out:
# 1453

# %%
# as whole data is missing we are replacing missing values with a new category
df['PoolQC'].fillna("missing",inplace=True)

# %%
df['PoolQC'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Missing values in 'Fence' column

# %%
df['Fence'].dtype
# Out:
# dtype('O')

# %%
df['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
df['Fence'].value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
sns.countplot(df['Fence'])
# Out:
# <AxesSubplot:xlabel='Fence', ylabel='count'>

# %%
df['Fence'].isnull().sum()
# Out:
# 1179

# %%
df['Fence'].fillna("missing",inplace=True)

# %%
df['Fence'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ###   Missing values in 'MiscFeature' column

# %%
df['MiscFeature'].dtype
# Out:
# dtype('O')

# %%
df['MiscFeature'].unique()
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
df['MiscFeature'].value_counts()
# Out:
# Shed    49
# Othr     2
# Gar2     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
sns.countplot(df['MiscFeature'])
# Out:
# <AxesSubplot:xlabel='MiscFeature', ylabel='count'>

# %%
df['MiscFeature'].isnull().sum()
# Out:
# 1406

# %%
#as more than 50% of data is missing so we are repalcing msising vlaues with a new category
df['MiscFeature'].fillna("Missing",inplace=True)

# %%
df['MiscFeature'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Handling categorical features

# %%
#there are 43 categorical features
len(categorical_cols)
# Out:
# 43

# %%
categorical_cols
# Out:
# ['LandContour',
#  'Neighborhood',
#  'MasVnrType',
#  'BsmtFinType1',
#  'LotConfig',
#  'BsmtCond',
#  'PavedDrive',
#  'BsmtExposure',
#  'LotShape',
#  'Utilities',
#  'SaleCondition',
#  'Condition1',
#  'Street',
#  'FireplaceQu',
#  'GarageType',
#  'SaleType',
#  'BsmtQual',
#  'GarageCond',
#  'ExterQual',
#  'BldgType',
#  'GarageFinish',
#  'MSZoning',
#  'RoofMatl',
#  'BsmtFinType2',
#  'PoolQC',
#  'Condition2',
#  'HouseStyle',
#  'RoofStyle',
#  'Alley',
#  'Exterior1st',
#  'ExterCond',
#  'CentralAir',
#  'Exterior2nd',
#  'LandSlope',
#  'HeatingQC',
#  'Heating',
#  'Fence',
#  'Functional',
#  'Electrical',
#  'Foundation',
#  'GarageQual',
#  'KitchenQual',
#  'MiscFeature']

# %% [markdown]
# ### Making all the categories declared as rare whose count is less than 1% in a categorical feature

# %%
for i in categorical_cols:
    temp = df.groupby(i)['SalePrice'].count()/len(df)
    temp_df = temp[temp>0.01].index
    df[i]=np.where(df[i].isin(temp_df),df[i],'Rar_var')

# %%
df.head(31)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0           60       RL    65.000000     8450   Pave  Missing      Reg
# 1           20       RL    80.000000     9600   Pave  Missing      Reg
# 2           60       RL    68.000000    11250   Pave  Missing      IR1
# 3           70       RL    60.000000     9550   Pave  Missing      IR1
# 4           60       RL    84.000000    14260   Pave  Missing      IR1
# 5           50       RL    85.000000    14115   Pave  Missing      IR1
# 6           20       RL    75.000000    10084   Pave  Missing      Reg
# 7           60       RL    70.049958    10382   Pave  Missing      IR1
# 8           50       RM    51.000000     6120   Pave  Missing      Reg
# 9          190       RL    50.000000     7420   Pave  Missing      Reg
# 10          20       RL    70.000000    11200   Pave  Missing      Reg
# 11          60       RL    85.000000    11924   Pave  Missing      IR1
# ...

# %% [markdown]
# ### converting 'categorical variable' to 'numerical variable'

# %%
for i in categorical_cols:
    lp = df.groupby(i)['SalePrice'].mean().sort_values().to_dict()
    ordinal_labels = {k:i for i,k in enumerate(lp,0)}
    df[i]=df[i].map(ordinal_labels)

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          60         3         65.0     8450       1      2         0
# 1          20         3         80.0     9600       1      2         0
# 2          60         3         68.0    11250       1      2         1
# 3          70         3         60.0     9550       1      2         1
# 4          60         3         84.0    14260       1      2         1
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0            1          1          0  ...         0       0      4
# 1            1          1          1  ...         0       0      4
# 2            1          1          0  ...         0       0      4
# 3            1          1          2  ...         0       0      4
# 4            1          1          1  ...         0       0      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Removing features which are highly correlated to each other

# %%
X= df.drop('SalePrice',axis=1)
y= df['SalePrice']

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
list_columns= []
df_corr = X.corr()
for i in range(len(X.corr().columns)):
    for j in range(i):
        if(abs(X.corr().iloc[i,j])>0.75):
          list_columns.append(df_corr.columns[i])

# %%
list_columns
# Out:
# ['Exterior2nd',
#  '1stFlrSF',
#  'TotRmsAbvGrd',
#  'FireplaceQu',
#  'GarageYrBlt',
#  'GarageArea',
#  'PoolQC']

# %%
X.drop(list_columns,axis=1,inplace=True)

# %%
X
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      2         0
# 1             20         3         80.0     9600       1      2         0
# 2             60         3         68.0    11250       1      2         1
# 3             70         3         60.0     9550       1      2         1
# 4             60         3         84.0    14260       1      2         1
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3         62.0     7917       1      2         0
# 1456          20         3         85.0    13175       1      2         0
# 1457          70         3         66.0     9042       1      2         0
# 1458          20         3         68.0     9717       1      2         0
# 1459          20         3         75.0     9937       1      2         0
#
#       LandContour  Utilities  LotConfig  ...  3SsnPorch  ScreenPorch  \
# ...

# %% [markdown]
# ### Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %% [markdown]
# ### Model Creation

# %%
# no scaling is required as we are going to use random forest regressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
params = { 'n_estimators':[int(x) for x in np.linspace(100,1000,10)],
           'min_samples_leaf':[1,2,3,5,10,15,18,24,32,64],
         'max_depth':[int(x) for x in np.linspace(2,50,30)]}
rf = RandomForestRegressor()
rf_cv = RandomizedSearchCV(estimator=rf,param_distributions=params,n_jobs=-1,verbose=True,cv=5,n_iter=100)
rf_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:    2.1s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-6d3f7638c1b0> in <module>
#       7 rf = RandomForestRegressor()
#       8 rf_cv = RandomizedSearchCV(estimator=rf,param_distributions=params,n_jobs=-1,verbose=True,cv=5,n_iter=100)
# ----> 9 rf_cv.fit(X_train,y_train)
#
# c:\users\ayush\.conda\envs\titanic\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ...

# %%
rf_cv.best_score_

# %%
rf_cv.score(X_test,y_test)

# %%
rf_cv.best_params_
